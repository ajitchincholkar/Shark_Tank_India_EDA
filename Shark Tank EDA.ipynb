# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
plt.style.use('fivethirtyeight')

# %% [markdown]
# ### Importing Dataset

# %%
df = pd.read_csv('H:/Downloads/Shark_Tank_India_S1.csv')

# %%
df.head()
# Out:
#    episode_number  startup_number           brand_name  \
# 0               1               1  BluePine Industries
# 1               1               2        Booz scooters
# 2               1               3  Heart up my Sleeves
# 3               2               4           Tagz Foods
# 4               2               5       Head and Heart
#
#                                      description  deal_offered  \
# 0                                   Frozen Momos             1
# 1  Renting e-bike for mobility in private spaces             1
# 2                             Detachable Sleeves             1
# 3                           Healthy Potato Chips             1
# 4                       Brain Development Course             0
#
#    startup_ask_amount_lakhs  startup_ask_percentage  startup_ask_valuation  \
# 0                      50.0                     5.0                1000.00
# 1                      40.0                    15.0                 266.67
# ...

# %% [markdown]
# ## Categorical
# - episode_number
# - deal_offered
# - loan_element_present
# - rannvijay_present
# - abish_present
# - aman_present
# - aman_invested
# - anupam_present
# - anupam_invested
# - ashneer_present
# - ashneer_invested
# - ghazal_present
# - ghazal_invested
# - namita_present
# - namita_invested
# - peyush_present
# - peyush_invested
# - vineeta_present
# - vineeta_invested
# - sharks_offering
#
# ## Numerical
# - startup_ask_amount_lakhs
# - startup_ask_percentage
# - startup_ask_valuation
# - deal_amount_lakhs
# - deal_equity
# - deal_valuation
# - loan_amount
# - amount_per_shark
# - equity_per_shark

# %% [markdown]
# ### Checking data types of columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   episode_number            121 non-null    int64
#  1   startup_number            121 non-null    int64
#  2   brand_name                121 non-null    object
#  3   description               121 non-null    object
#  4   deal_offered              121 non-null    int64
#  5   startup_ask_amount_lakhs  121 non-null    float64
#  6   startup_ask_percentage    121 non-null    float64
#  7   startup_ask_valuation     121 non-null    float64
#  8   deal_amount_lakhs         121 non-null    float64
#  9   deal_equity               121 non-null    float64
#  10  deal_valuation            121 non-null    float64
#  11  loan_element_present      121 non-null    int64
#  12  loan_amount               121 non-null    int64
# ...

# %% [markdown]
# ### Checking for null values

# %%
df.isnull().sum()
# Out:
# episode_number              0
# startup_number              0
# brand_name                  0
# description                 0
# deal_offered                0
# startup_ask_amount_lakhs    0
# startup_ask_percentage      0
# startup_ask_valuation       0
# deal_amount_lakhs           0
# deal_equity                 0
# deal_valuation              0
# loan_element_present        0
# loan_amount                 0
# rannvijay_present           0
# abish_present               0
# aman_present                0
# aman_invested               0
# anupam_present              0
# anupam_invested             0
# ashneer_present             0
# ashneer_invested            0
# ghazal_present              0
# ghazal_invested             0
# namita_present              0
# namita_invested             0
# peyush_present              0
# peyush_invested             0
# vineeta_present             0
# vineeta_invested            0
# sharks_offering             0
# amount_per_shark            0
# ...

# %% [markdown]
# ### Mathematical Overview

# %%
df.describe().transpose()
# Out:
#                           count         mean           std      min     25%  \
# episode_number            121.0    19.305785     10.375326  1.00000   11.00
# startup_number            121.0    61.000000     35.073732  1.00000   31.00
# deal_offered              121.0     0.561983      0.498206  0.00000    0.00
# startup_ask_amount_lakhs  121.0   312.338851   2721.640471  0.00101   45.00
# startup_ask_percentage    121.0     5.083306      3.882554  0.25000    2.00
# startup_ask_valuation     121.0  4230.182727  12329.894575  0.01000  666.67
# deal_amount_lakhs         121.0    31.925629     36.847011  0.00000    0.00
# deal_equity               121.0     8.799421     12.948175  0.00000    0.00
# deal_valuation            121.0   473.770826    925.693471  0.00000    0.00
# loan_element_present      121.0     0.074380      0.263480  0.00000    0.00
# loan_amount               121.0     2.900826     12.150724  0.00000    0.00
# ...

# %% [markdown]
# ### How many startups got the deal ?

# %%
print(df['deal_offered'].value_counts())
df['deal_offered'].value_counts().plot(kind='pie',autopct='%0.1f%%')
plt.show()
# Out:
# 1    68
# 0    52
# Name: deal_offered, dtype: int64

# %% [markdown]
# ### What amount of money most startups asked for?

# %%
avg_amt_ask = round(df['startup_ask_amount_lakhs'].mean(),2)
print('Average amount of money asked by startups : ' + str(avg_amt_ask) + ' lakhs')
plt.figure(figsize=(15,7))
sns.countplot(df['startup_ask_amount_lakhs'])
plt.xticks(rotation=60)
plt.show()
# Out:
# Average amount of money asked by startups : 64.94 lakhs

# %%
# Removed the outlier of 30000 lakhs because it was making the mean skewed

df = df[df['startup_ask_amount_lakhs'] != 30000]
sns.boxplot(df['startup_ask_amount_lakhs'])
# Out:
# <AxesSubplot:xlabel='startup_ask_amount_lakhs'>

# %% [markdown]
# ### What percent of their company were most owners offering?

# %%
df['startup_ask_percentage'].nunique()  # Only 18 unique ask percentages.Hence, countplot
avg_percent = round(df['startup_ask_percentage'].mean())
print('Average percent of company offered : ' + str(avg_percent))
plt.figure(figsize=(15,7))
sns.countplot(df['startup_ask_percentage'])
plt.xticks(rotation=60)
plt.show()
# Out:
# Average percent of company offered : 5

# %% [markdown]
# ### At what amounts were majority of deals closed?

# %%
deal_amount = df[df['deal_amount_lakhs'] != 0]
print("Average deal amount : " +  str(deal_amount['deal_amount_lakhs'].mean()))
plt.figure(figsize=(15,7))
sns.countplot(deal_amount['deal_amount_lakhs'])
plt.xticks(rotation=60)
plt.show()
# Out:
# Average deal amount : 57.65673223880597

# %% [markdown]
# ### At what equity majority of the deals closed?

# %%
print("Average deal equity = " + str(round(deal_amount['deal_equity'].mean(),2)))
plt.figure(figsize=(15,7))
sns.countplot(deal_amount['deal_equity'])
plt.xticks(rotation=60)
plt.show()
# Out:
# Average deal equity = 15.89

# %% [markdown]
# ### At what valuation majority of the deals closed?

# %%
print("Average deal valuation : " +  str(deal_amount['deal_valuation'].mean()))
plt.figure(figsize=(15,7))
sns.countplot(deal_amount['deal_valuation'])
plt.xticks(rotation=60)
plt.show()
# Out:
# Average deal valuation : 855.6159701492538

# %% [markdown]
# ### What percent of deals containted loan element?

# %%
print((deal_amount['loan_element_present'].value_counts()))
deal_amount['loan_element_present'].value_counts().plot(kind='pie',autopct='%0.1f%%')
plt.plot()
# Out:
# 0    58
# 1     9
# Name: loan_element_present, dtype: int64
# []

# %%
# Average loan given

loan_present = df[df['loan_element_present'] == 1]
print("Average loan given : " + str(loan_present['loan_amount'].mean()))
# Out:
# Average loan given : 39.0

# %%
# Dropping unuseful columns

df.drop(['rannvijay_present','abish_present'], axis=1, inplace=True)

# %% [markdown]
# ### Which shark was present during the most number of pitch decks?

# %%
def shark_present(name):
    print(name.title() + ' Present')
    print(df[name.lower()+'_present'].value_counts())
    df[name.lower()+'_present'].value_counts().plot(kind='pie', autopct='%0.1f%%')

# %%
shark_present('aman')
# Out:
# Aman Present
# 1    101
# 0     19
# Name: aman_present, dtype: int64

# %%
shark_present('anupam')
# Out:
# Anupam Present
# 1    120
# Name: anupam_present, dtype: int64

# %%
shark_present('ashneer')
# Out:
# Ashneer Present
# 1    97
# 0    23
# Name: ashneer_present, dtype: int64

# %%
shark_present('namita')
# Out:
# Namita Present
# 1    109
# 0     11
# Name: namita_present, dtype: int64

# %%
shark_present('peyush')
# Out:
# Peyush Present
# 1    91
# 0    29
# Name: peyush_present, dtype: int64

# %%
shark_present('vineeta')
# Out:
# Vineeta Present
# 1    70
# 0    50
# Name: vineeta_present, dtype: int64

# %%
shark_present('ghazal')
# Out:
# Ghazal Present
# 0    94
# 1    26
# Name: ghazal_present, dtype: int64

# %% [markdown]
# ### Sharks present during how many pitch decks
# - Anupam was present during 120 (100%) pitch decks.
# - Namita was present during 109 (91%) pitch decks.
# - Aman was present during 101 (84%) pitch decks.
# - Ashneer was present during 97 (81%) pitch decks.
# - Peyush was present during 91 (76%) pitch decks.
# - Vineeta was present during 70 (58%) pitch decks.
# - Ghazal was present during 26 (22%) pitch decks.

# %%
plt.figure(figsize=(15,7))
sharks_together = df[df['sharks_offering'] != 0]
print(sharks_together['sharks_offering'].value_counts())
sharks_together['sharks_offering'].value_counts().plot(kind='pie',autopct='%0.1f%%')
plt.show()
# Out:
# 1    22
# 2    21
# 3    15
# 4     5
# 5     4
# Name: sharks_offering, dtype: int64

# %% [markdown]
# ### Average money invested by a shark on a single deal

# %%
money_per_shark = df[df['amount_per_shark'] != 0]
avg_money = round(money_per_shark['amount_per_shark'].mean())
avg_equi = round(money_per_shark['equity_per_shark'].mean())
print('Average amount invested by shark on single deal is ' + str(avg_money) + ' lakhs.')
print('Average equity per shark : ' + str(avg_equi) + '%')
# Out:
# Average amount invested by shark on single deal is 33 lakhs.
# Average equity per shark : 10%

# %% [markdown]
# ### Checking correlation between columns

# %%
ht = df.drop(['episode_number','startup_number','loan_element_present'],axis=1).corr()
plt.figure(figsize=(15,7))
sns.heatmap(ht)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Which shark invested in most startups (% wise)?

# %%
def shark_invested(name):
    temp_df = df[df[name.lower()+'_present'] == 1]
    print(name.title() + ' Invested')
    print(temp_df[name.lower()+'_invested'].value_counts())
    temp_df[name.lower()+'_invested'].value_counts().plot(kind='pie', autopct='%0.0f%%')

# %%
shark_invested('aman')
# Out:
# Aman Invested
# 0    72
# 1    29
# Name: aman_invested, dtype: int64

# %%
shark_invested('anupam')
# Out:
# Anupam Invested
# 0    96
# 1    24
# Name: anupam_invested, dtype: int64

# %%
shark_invested('ashneer')
# Out:
# Ashneer Invested
# 0    76
# 1    21
# Name: ashneer_invested, dtype: int64

# %%
shark_invested('namita')
# Out:
# Namita Invested
# 0    85
# 1    24
# Name: namita_invested, dtype: int64

# %%
shark_invested('peyush')
# Out:
# Peyush Invested
# 0    63
# 1    28
# Name: peyush_invested, dtype: int64

# %%
shark_invested('vineeta')
# Out:
# Vineeta Invested
# 0    54
# 1    16
# Name: vineeta_invested, dtype: int64

# %%
shark_invested('ghazal')
# Out:
# Ghazal Invested
# 0    19
# 1     7
# Name: ghazal_invested, dtype: int64

# %% [markdown]
# ### Which shark invested in most startups (% wise) ?
# - Peyush invested in 28 startups out of 91 (31%)
# - Aman invested in 29 startups out of 101 (29%)
# - Ghazal invested in 7 startups out of 26 (27%)
# - Vineeta invested in 16 startups out of 70 (23%)
# - Namita invested in 24 startups out of 109 (22%)
# - Ashneer invested in 21 startups out of 97 (22%)
# - Anupam invested in 24 startups out of 120 (20%)

# %% [markdown]
# ### How much money did each shark invest in season 1 ?

# %%
def amount_invested_by_shark(name):
    temp_df = df[df[name.lower()+'_invested'] == 1]
    amount = temp_df['amount_per_shark'].sum()
    print('Amount invested by '+ name.title() + ' is ' + str(round((amount),1)) + ' lakhs ' + '(' + str(round((amount/100),2)) + 'cr).')

sharks=['aman','anupam','ashneer','peyush','namita','vineeta','ghazal']

for shark in sharks:
    amount_invested_by_shark(shark)
# Out:
# Amount invested by Aman is 894.5 lakhs (8.95cr).
# Amount invested by Anupam is 533.8 lakhs (5.34cr).
# Amount invested by Ashneer is 494.3 lakhs (4.94cr).
# Amount invested by Peyush is 769.7 lakhs (7.7cr).
# Amount invested by Namita is 705.3 lakhs (7.05cr).
# Amount invested by Vineeta is 335.3 lakhs (3.35cr).
# Amount invested by Ghazal is 130.0 lakhs (1.3cr).

# %%
amount_viz = {'shark':['Aman','Anupam','Ashneer','Peyush','Namita','Vineeta','Ghazal'],'Amount(cr)':[8.95,5.34,4.94,7.7,7.05,3.35,1.3]}
invested_per_shark = pd.DataFrame(amount_viz)
invested_per_shark.sort_values('Amount(cr)',ascending=False,inplace=True)
plt.figure(figsize=(14,6))
plt.bar(x='shark',height='Amount(cr)',data=invested_per_shark)
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# ## Which shark invested the most amount of money?
# - Aman invested 8.95 cr
# - Peyush invested 7.7 cr
# - Namita invested 7.05 cr
# - Anupam invested 5.34 cr
# - Ashneer invested 4.94 cr
# - Vineeta invested 3.35 cr
# - Ghazal invested 1.3 cr
